# %% [markdown]
# ### Mr. Tuấn Anh

# %%
import numpy as np
x = np.random.randint(1,100,100)
print(x)
print(type(x))
# Out:
# [18 89 82 33 20 82 56 84  2 13 29 50 56 42 81 19 60 93 49 41 51 11 36 36
#  17 15 56 96 22  3 76 80 17 98 57 36 77 88  4 71  3 78 36 99 85 97 98 94
#  47 26 25  4 75 25 49  8 74 27 54 24  2  9  5 82 48 97 92  5  3 18 39 59
#  76 78 66 97 52 79 13 96 36 97 33 96 85 73 76 50 71 93 67 27  4 95 52 37
#  31 42 93 33]
# <class 'numpy.ndarray'>

# %%
import matplotlib.pyplot as plt
plt.plot(x)
plt.title('Đồ thị gốc X')
plt.show()

# %%
def find_max(ds):
    max_value = ds[0] 
    for num in ds:
     if num > max_value:
        max_value = num
    return max_value
list_data = x 
max_value_data = find_max(list_data)
print("Giá trị lớn nhất trong dãy số là:", max_value_data)
# Out:
# Giá trị lớn nhất trong dãy số là: 99

# %%
a = max(list_data)
print(a)
# Out:
# 99

# %%
def find_min(ds):
    min_value = ds[0] 
    for num in ds:
     if num < min_value:
        min_value = num
    return min_value
min_value_data = find_min(list_data)
print("Giá trị nho nhất trong dãy số là:", min_value_data)
# Out:
# Giá trị nho nhất trong dãy số là: 2

# %%
def normalization(list_data):
    normal_list = []
    for i in list_data:
        a = (i-min_value_data)/(max_value_data - min_value_data)
        normal_list.append(a)
    return normal_list
a = normalization(list_data)
print(a)
# Out:
# [0.16494845360824742, 0.8969072164948454, 0.8247422680412371, 0.31958762886597936, 0.18556701030927836, 0.8247422680412371, 0.5567010309278351, 0.845360824742268, 0.0, 0.1134020618556701, 0.27835051546391754, 0.4948453608247423, 0.5567010309278351, 0.41237113402061853, 0.8144329896907216, 0.17525773195876287, 0.5979381443298969, 0.9381443298969072, 0.4845360824742268, 0.4020618556701031, 0.5051546391752577, 0.09278350515463918, 0.35051546391752575, 0.35051546391752575, 0.15463917525773196, 0.13402061855670103, 0.5567010309278351, 0.9690721649484536, 0.20618556701030927, 0.010309278350515464, 0.7628865979381443, 0.8041237113402062, 0.15463917525773196, 0.9896907216494846, 0.5670103092783505, 0.35051546391752575, 0.7731958762886598, 0.8865979381443299, 0.020618556701030927, 0.711340206185567, 0.010309278350515464, 0.7835051546391752, 0.35051546391752575, 1.0, 0.8556701030927835, 0.979381443298969, 0.9896907216494846, 0.9484536082474226, 0.4639175257731959, 0.24742268041237114, 0.23711340206185566, 0.020618556701030927, 0.7525773195876289, 0.23711340206185566, 0.4845360824742268, 0.061855670103092786, 0.7422680412371134, 0.25773195876288657, 0.5360824742268041, 0.2268041237113402, 0.0, 0.07216494845360824, 0.030927835051546393, 0.8247422680412371, 0.4742268041237113, 0.979381443298969, 0.9278350515463918, 0.030927835051546393, 0.010309278350515464, 0.16494845360824742, 0.38144329896907214, 0.5876288659793815, 0.7628865979381443, 0.7835051546391752, 0.6597938144329897, 0.979381443298969, 0.5154639175257731, 0.7938144329896907, 0.1134020618556701, 0.9690721649484536, 0.35051546391752575, 0.979381443298969, 0.31958762886597936, 0.9690721649484536, 0.8556701030927835, 0.7319587628865979, 0.7628865979381443, 0.4948453608247423, 0.711340206185567, 0.9381443298969072, 0.6701030927835051, 0.25773195876288657, 0.020618556701030927, 0.9587628865979382, 0.5154639175257731, 0.36082474226804123, 0.29896907216494845, 0.41237113402061853, 0.9381443298969072, 0.31958762886597936]

# %%
print(type(list_data))
# Out:
# <class 'numpy.ndarray'>

# %%
# Tính normalization

list_data_nor = (list_data-min_value_data)/(max_value_data - min_value_data)
print(list_data_nor)
# Out:
# [0.16494845 0.89690722 0.82474227 0.31958763 0.18556701 0.82474227
#  0.55670103 0.84536082 0.         0.11340206 0.27835052 0.49484536
#  0.55670103 0.41237113 0.81443299 0.17525773 0.59793814 0.93814433
#  0.48453608 0.40206186 0.50515464 0.09278351 0.35051546 0.35051546
#  0.15463918 0.13402062 0.55670103 0.96907216 0.20618557 0.01030928
#  0.7628866  0.80412371 0.15463918 0.98969072 0.56701031 0.35051546
#  0.77319588 0.88659794 0.02061856 0.71134021 0.01030928 0.78350515
#  0.35051546 1.         0.8556701  0.97938144 0.98969072 0.94845361
#  0.46391753 0.24742268 0.2371134  0.02061856 0.75257732 0.2371134
#  0.48453608 0.06185567 0.74226804 0.25773196 0.53608247 0.22680412
#  0.         0.07216495 0.03092784 0.82474227 0.4742268  0.97938144
#  0.92783505 0.03092784 0.01030928 0.16494845 0.3814433  0.58762887
#  0.7628866  0.78350515 0.65979381 0.97938144 0.51546392 0.79381443
#  0.11340206 0.96907216 0.35051546 0.97938144 0.31958763 0.96907216
#  0.8556701  0.73195876 0.7628866  0.49484536 0.71134021 0.93814433
#  0.67010309 0.25773196 0.02061856 0.95876289 0.51546392 0.36082474
#  0.29896907 0.41237113 0.93814433 0.31958763]

# %%
# Đồ thị sau khi Normalization

plt.plot(list_data_nor)
plt.title('X sau khi Normalization')
plt.show()

# %% [markdown]
# ### Ms. Hong

# %%
# Cách 3: tính mean

def tinh_mean_c1(listx):
    sum =  0
    for i in listx:
        sum += i 
    meanx = sum/len(listx)    
    return meanx

tinh_mean_c1(x)
# Out:
# 51.81

# %%
# Cách 2: tính mean

def tinh_mean_c2(listx):
    sum =  np.sum(listx)
    meanx = sum/len(listx)    
    return meanx

tinh_mean_c2(x)
# Out:
# 51.81

# %%
# Cách 3: tính mean

def tinh_mean_c3(listx):
    sizex = np.size(listx)
    sum = np.sum(listx)
    # sum =  0
    # for i in listx:
    #     sum += i 
    meanx = sum/sizex    
    return meanx

tinh_mean_c3(x)
# Out:
# 51.81

# %% [markdown]
# ### Mr. Đào Anh

# %%
# Tính độ lệch chuẩn standard

def standard(data):
    size = np.size(data)
    y = np.sum((data - tinh_mean_c3(data))**2)
    z = y / size
    std = np.sqrt(z)

    return std

result = standard(x)
print(result)
# Out:
# 31.222330150070476

# %%
# Tính Standardization

def Standardization(data):
    Stand_data = (data - tinh_mean_c3(data))/standard(data)
    return Stand_data

result1 = Standardization(x)
result1
# Out:
# array([-1.08287882,  1.19113467,  0.96693616, -0.60245343, -1.0188221 ,
#         0.96693616,  0.13419882,  1.03099288, -1.59533256, -1.24302061,
#        -0.73056687, -0.05797133,  0.13419882, -0.3141982 ,  0.9349078 ,
#        -1.05085046,  0.26231226,  1.31924811, -0.08999969, -0.34622656,
#        -0.02594297, -1.30707733, -0.50636836, -0.50636836, -1.11490718,
#        -1.1789639 ,  0.13419882,  1.41533319, -0.95476538, -1.5633042 ,
#         0.77476601,  0.90287944, -1.11490718,  1.4793899 ,  0.16622718,
#        -0.50636836,  0.80679436,  1.15910631, -1.53127585,  0.61462421,
#        -1.5633042 ,  0.83882272, -0.50636836,  1.51141826,  1.06302124,
#         1.44736154,  1.4793899 ,  1.35127647, -0.15405641, -0.82665195,
#        -0.85868031, -1.53127585,  0.74273765, -0.85868031, -0.08999969,
#        -1.40316241,  0.71070929, -0.79462359,  0.07014211, -0.89070866,
#        -1.59533256, -1.37113405, -1.49924749,  0.96693616, -0.12202805,
#         1.44736154,  1.28721975, -1.49924749, -1.5633042 , -1.08287882,
#        -0.41028328,  0.2302839 ,  0.77476601,  0.83882272,  0.45448241,
#         1.44736154,  0.00608539,  0.87085108, -1.24302061,  1.41533319,
#        -0.50636836,  1.44736154, -0.60245343,  1.41533319,  1.06302124,
#         0.67868093,  0.77476601, -0.05797133,  0.61462421,  1.31924811,
#         0.48651077, -0.79462359, -1.53127585,  1.38330483,  0.00608539,
#        -0.47434   , -0.66651015, -0.3141982 ,  1.31924811, -0.60245343])

# %%
# Đồ thị sau khi standardization

plt.plot(result1)
plt.title('X sau khi standardization')
plt.show()

# %%
plt.figure(figsize=(20,6))
plt.subplot(1,3,1)
plt.plot(x)
plt.title('Đồ thị gốc X')

plt.subplot(1,3,2)
plt.plot(list_data_nor)
plt.title('Normalization')

plt.subplot(1,3,3)
plt.plot(result1)
plt.title('Standardization')
plt.show()

# %% [markdown]
# - Dữ liệu X sau khi Normalization : hình dạng đồ thị vẫn giống hình dạng của đồ thị gốc X. Tuy nhiên, giá trị trục Y được thu gọn theo công thức : $$X_{norm} = \frac{X_{i} - X_{min}}{X_{max} - X_{min}}$$
# >>>> Như đồ thị (2) trên ta có thể thấy: Sau khi Normalization, giá trị chỉ từ: 0 -> 1 (thay vì 0 -> 100).
#
# - Dữ liệu X sau khi Standardization : hình dạng đồ thị vẫn giống hình dạng của đồ thị gốc X. Tuy nhiên, giá trị trục Y được thu gọn theo công thức : $$z = \frac{x - \mu}{\sigma}$$
# >>>> Như đồ thị (3) trên ta có thể thấy: Sau khi Standardization, giá trị chỉ từ: ~2 -> 2 (thay vì 0 -> 100) và đối xứng qua trục X.
